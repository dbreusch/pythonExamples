# %% [markdown]
# Simple global map plot
# ---
# Create a global Mollweide projection with coastlines

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap, addcyclic, shiftgrid

# from netCDF4 import Dataset
# import numpy as np
# from model import Model
# from GCNet import GCNet
# import math

# %%
fig1 = plt.figure( figsize=(12,8) )
# fig.subplots_adjust(left=0., right=1., bottom=0., top=0.9)
mGbl = Basemap(projection='moll', llcrnrlat=-90, urcrnrlat=90, \
               llcrnrlon=0, urcrnrlon=360, resolution='c', lon_0=0)
mGbl.drawcoastlines()
mGbl.drawmapboundary
# Out:
# <bound method Basemap.drawmapboundary of <mpl_toolkits.basemap.Basemap object at 0x10fe84650>>
